# %% [markdown]
# # LetsGrowMore Sept_2022

# %% [markdown]
# ### Name - Nirmal Kuiry

# %% [markdown]
# ### Task-1 : Stock Market Prediction And Forcasting Using Stacked LSTM
# ### Dataset : https://github.com/Nirmal2411-ds/LGM-Data-Science-Project/blob/main/NSE-TATAGLOBAL.csv
# ### Level : Beginner
# ### Language : Python
# ### Software : Jupyter Notebook

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Reading The Dataset

# %%
stk = pd.read_csv(r"C:\\Users\\USER\\Downloads\\NSE-TATAGLOBAL.csv")

# %%
stk.head() # Prints first Five Rows
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
stk.tail() # Prints last five rows
# Out:
#             Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2030  2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
# 2031  2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2032  2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2033  2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2034  2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
#
#       Turnover (Lacs)
# 2030           694.98
# 2031           780.01
# 2032           340.31
# 2033           355.17
# 2034           803.56

# %%
stk.describe() # Gives Statistical information like Mean, Median, Count, Standard deviation, Minimum value, Maximum value
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
stk.isnull() # Calculating null values in the Dataset
# Out:
#        Date   Open   High    Low   Last  Close  Total Trade Quantity  \
# 0     False  False  False  False  False  False                 False
# 1     False  False  False  False  False  False                 False
# 2     False  False  False  False  False  False                 False
# 3     False  False  False  False  False  False                 False
# 4     False  False  False  False  False  False                 False
# ...     ...    ...    ...    ...    ...    ...                   ...
# 2030  False  False  False  False  False  False                 False
# 2031  False  False  False  False  False  False                 False
# 2032  False  False  False  False  False  False                 False
# 2033  False  False  False  False  False  False                 False
# 2034  False  False  False  False  False  False                 False
#
#       Turnover (Lacs)
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 2030            False
# 2031            False
# 2032            False
# 2033            False
# 2034            False
#
# [2035 rows x 8 columns]

# %% [markdown]
# ## Sorting The Data

# %%
stk['Date']=pd.to_datetime(stk['Date'])
print(type(stk.Date[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df=stk.sort_values(by='Date')
df.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
df.reset_index(inplace=True) # Reset the index of the Dataframe

# %%
df.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %% [markdown]
# ## Data Visualization

# %%
plt.plot(df['Close'])

# %%
dff=df['Close']
dff
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %% [markdown]
# ## Min Max Scaler

# %%
scaler=MinMaxScaler(feature_range=(0,1))
dff=scaler.fit_transform(np.array(dff).reshape(-1,1))
dff
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# ## Spliting The Dataset

# %%
training_size=int(len(dff)*0.70)
test_size=len(dff)-training_size
train_data,test_data=dff[0:training_size,:],dff[training_size:len(dff),:1]

# %% [markdown]
# ## Converting an Array of values into a Dataset matrix

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# ## Spliting the Data into Train and Test

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1323, 100)
# (1323,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (510, 100)
# (510,)
# (None, None)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %% [markdown]
# ## Creating the stacked LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_split=0.1,epochs=60,batch_size=64,verbose=1)
# Out:
# Epoch 1/60
# 19/19 [==============================] - 13s 268ms/step - loss: 0.0103 - val_loss: 0.0012
# Epoch 2/60
# 19/19 [==============================] - 4s 187ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 3/60
# 19/19 [==============================] - 3s 163ms/step - loss: 9.4465e-04 - val_loss: 0.0012
# Epoch 4/60
# 19/19 [==============================] - 3s 169ms/step - loss: 8.6244e-04 - val_loss: 0.0011
# Epoch 5/60
# 19/19 [==============================] - 4s 204ms/step - loss: 8.0996e-04 - val_loss: 0.0011
# Epoch 6/60
# 19/19 [==============================] - 3s 178ms/step - loss: 7.8760e-04 - val_loss: 0.0010
# Epoch 7/60
# 19/19 [==============================] - 4s 212ms/step - loss: 7.5253e-04 - val_loss: 9.8611e-04
# Epoch 8/60
# 19/19 [==============================] - 4s 204ms/step - loss: 7.3788e-04 - val_loss: 9.3437e-04
# Epoch 9/60
# 19/19 [==============================] - 4s 205ms/step - loss: 7.1387e-04 - val_loss: 9.0600e-04
# Epoch 10/60
# 19/19 [==============================] - 4s 213ms/step - loss: 6.9090e-04 - val_loss: 8.6588e-04
# Epoch 11/60
# 19/19 [==============================] - 4s 219ms/step - loss: 6.7589e-04 - val_loss: 8.5359e-04
# Epoch 12/60
# 19/19 [==============================] - 4s 204ms/step - loss: 6.7812e-04 - val_loss: 7.9352e-04
# Epoch 13/60
# 19/19 [==============================] - 4s 202ms/step - loss: 6.3925e-04 - val_loss: 8.4381e-04
# Epoch 14/60
# 19/19 [==============================] - 4s 213ms/step - loss: 6.3113e-04 - val_loss: 7.6973e-04
# Epoch 15/60
# 19/19 [==============================] - 4s 214ms/step - loss: 6.1696e-04 - val_loss: 6.9534e-04
# Epoch 16/60
# 19/19 [==============================] - 4s 200ms/step - loss: 6.0115e-04 - val_loss: 6.8866e-04
# Epoch 17/60
# 19/19 [==============================] - 4s 200ms/step - loss: 5.6898e-04 - val_loss: 6.5155e-04
# Epoch 18/60
# 19/19 [==============================] - 4s 215ms/step - loss: 5.9021e-04 - val_loss: 6.3595e-04
# Epoch 19/60
# 19/19 [==============================] - 4s 212ms/step - loss: 6.1165e-04 - val_loss: 8.4226e-04
# Epoch 20/60
# 19/19 [==============================] - 4s 201ms/step - loss: 6.2428e-04 - val_loss: 6.0003e-04
# Epoch 21/60
# 19/19 [==============================] - 4s 201ms/step - loss: 5.8782e-04 - val_loss: 6.0211e-04
# Epoch 22/60
# 19/19 [==============================] - 4s 214ms/step - loss: 5.2530e-04 - val_loss: 5.5295e-04
# Epoch 23/60
# 19/19 [==============================] - 4s 215ms/step - loss: 5.1025e-04 - val_loss: 5.5983e-04
# Epoch 24/60
# 19/19 [==============================] - 4s 203ms/step - loss: 4.9008e-04 - val_loss: 5.2155e-04
# Epoch 25/60
# 19/19 [==============================] - 4s 200ms/step - loss: 4.9229e-04 - val_loss: 5.3833e-04
# Epoch 26/60
# 19/19 [==============================] - 4s 214ms/step - loss: 4.7069e-04 - val_loss: 4.9918e-04
# Epoch 27/60
# 19/19 [==============================] - 4s 216ms/step - loss: 4.9705e-04 - val_loss: 4.8756e-04
# Epoch 28/60
# 19/19 [==============================] - 4s 203ms/step - loss: 4.6179e-04 - val_loss: 4.6507e-04
# Epoch 29/60
# 19/19 [==============================] - 4s 201ms/step - loss: 4.3812e-04 - val_loss: 4.4704e-04
# Epoch 30/60
# 19/19 [==============================] - 4s 215ms/step - loss: 4.3077e-04 - val_loss: 4.5246e-04
# Epoch 31/60
# 19/19 [==============================] - 4s 216ms/step - loss: 4.1605e-04 - val_loss: 4.1924e-04
# Epoch 32/60
# 19/19 [==============================] - 4s 202ms/step - loss: 4.2455e-04 - val_loss: 4.3475e-04
# Epoch 33/60
# 19/19 [==============================] - 4s 200ms/step - loss: 3.9443e-04 - val_loss: 3.9763e-04
# Epoch 34/60
# 19/19 [==============================] - 4s 216ms/step - loss: 3.7968e-04 - val_loss: 4.0456e-04
# Epoch 35/60
# 19/19 [==============================] - 4s 213ms/step - loss: 3.6719e-04 - val_loss: 4.6565e-04
# Epoch 36/60
# 19/19 [==============================] - 4s 199ms/step - loss: 3.6741e-04 - val_loss: 3.9826e-04
# Epoch 37/60
# 19/19 [==============================] - 4s 199ms/step - loss: 3.8246e-04 - val_loss: 3.5047e-04
# Epoch 38/60
# 19/19 [==============================] - 4s 217ms/step - loss: 3.7563e-04 - val_loss: 3.7962e-04
# Epoch 39/60
# 19/19 [==============================] - 4s 216ms/step - loss: 3.5645e-04 - val_loss: 3.2666e-04
# Epoch 40/60
# 19/19 [==============================] - 4s 200ms/step - loss: 3.4675e-04 - val_loss: 3.3765e-04
# Epoch 41/60
# 19/19 [==============================] - 4s 198ms/step - loss: 3.4533e-04 - val_loss: 3.1890e-04
# Epoch 42/60
# 19/19 [==============================] - 4s 215ms/step - loss: 3.3184e-04 - val_loss: 2.8401e-04
# Epoch 43/60
# 19/19 [==============================] - 4s 215ms/step - loss: 3.1118e-04 - val_loss: 3.1380e-04
# Epoch 44/60
# 19/19 [==============================] - 4s 201ms/step - loss: 2.9485e-04 - val_loss: 2.7879e-04
# Epoch 45/60
# 19/19 [==============================] - 4s 200ms/step - loss: 2.9539e-04 - val_loss: 2.5224e-04
# Epoch 46/60
# 19/19 [==============================] - 4s 215ms/step - loss: 2.7160e-04 - val_loss: 2.4407e-04
# Epoch 47/60
# 19/19 [==============================] - 4s 213ms/step - loss: 2.7507e-04 - val_loss: 2.3609e-04
# Epoch 48/60
# 19/19 [==============================] - 4s 202ms/step - loss: 2.7697e-04 - val_loss: 2.2836e-04
# Epoch 49/60
# 19/19 [==============================] - 4s 200ms/step - loss: 3.4755e-04 - val_loss: 2.6092e-04
# Epoch 50/60
# 19/19 [==============================] - 4s 211ms/step - loss: 2.9323e-04 - val_loss: 2.3001e-04
# Epoch 51/60
# 19/19 [==============================] - 4s 216ms/step - loss: 2.6645e-04 - val_loss: 2.2688e-04
# Epoch 52/60
# 19/19 [==============================] - 4s 203ms/step - loss: 2.3763e-04 - val_loss: 2.4575e-04
# Epoch 53/60
# 19/19 [==============================] - 4s 203ms/step - loss: 2.3818e-04 - val_loss: 2.0466e-04
# Epoch 54/60
# 19/19 [==============================] - 4s 214ms/step - loss: 2.2375e-04 - val_loss: 2.1164e-04
# Epoch 55/60
# 19/19 [==============================] - 4s 217ms/step - loss: 2.2435e-04 - val_loss: 1.9201e-04
# Epoch 56/60
# 19/19 [==============================] - 4s 207ms/step - loss: 2.1900e-04 - val_loss: 1.9391e-04
# Epoch 57/60
# 19/19 [==============================] - 4s 202ms/step - loss: 2.0791e-04 - val_loss: 1.8302e-04
# Epoch 58/60
# 19/19 [==============================] - 4s 216ms/step - loss: 2.0703e-04 - val_loss: 1.9451e-04
# Epoch 59/60
# 19/19 [==============================] - 4s 215ms/step - loss: 1.9712e-04 - val_loss: 1.7297e-04
# Epoch 60/60
# 19/19 [==============================] - 4s 205ms/step - loss: 2.0384e-04 - val_loss: 1.7271e-04

# %% [markdown]
# ## Prediction and Checking Performance

# %%
test_predict=model.predict(X_test)
# Out:
# 16/16 [==============================] - 3s 57ms/step

# %%
test_predicted=scaler.inverse_transform(test_predict)
test_predicted
# Out:
# array([[141.55728 ],
#        [141.74472 ],
#        [140.85114 ],
#        [138.18474 ],
#        [136.47798 ],
#        [135.93233 ],
#        [137.13896 ],
#        [138.77753 ],
#        [139.20818 ],
#        [138.78549 ],
#        [138.44427 ],
#        [139.55424 ],
#        [140.37328 ],
#        [141.9664  ],
#        [144.19322 ],
#        [142.25627 ],
#        [139.768   ],
#        [139.31775 ],
#        [139.99814 ],
#        [145.08336 ],
#        [149.6901  ],
#        [151.92525 ],
#        [152.1564  ],
#        [149.93524 ],
#        [149.5922  ],
#        [149.41318 ],
#        [149.91763 ],
#        [151.68433 ],
#        [152.48288 ],
#        [152.44568 ],
#        [152.72101 ],
#        [151.4891  ],
#        [148.17545 ],
#        [142.42398 ],
#        [138.86786 ],
#        [137.826   ],
#        [138.03693 ],
#        [137.3202  ],
#        [135.01909 ],
#        [131.27658 ],
#        [128.62907 ],
#        [127.37514 ],
#        [125.37725 ],
#        [124.58023 ],
#        [122.65097 ],
#        [120.09894 ],
#        [119.349976],
#        [119.08737 ],
#        [119.39021 ],
#        [118.55165 ],
#        [117.68325 ],
#        [117.247215],
#        [116.4599  ],
#        [116.57063 ],
#        [117.88716 ],
#        [119.70643 ],
#        [121.66978 ],
#        [122.47671 ],
#        [122.21283 ],
#        [122.14254 ],
#        [122.26581 ],
#        [122.139015],
#        [122.365   ],
#        [122.80261 ],
#        [123.05662 ],
#        [123.12477 ],
#        [122.9253  ],
#        [123.169426],
#        [123.58662 ],
#        [123.923775],
#        [123.17552 ],
#        [122.149925],
#        [120.762505],
#        [119.47698 ],
#        [118.16267 ],
#        [118.229965],
#        [118.819824],
#        [119.802956],
#        [120.89972 ],
#        [122.10664 ],
#        [123.22578 ],
#        [123.89862 ],
#        [124.30391 ],
#        [124.29693 ],
#        [124.11464 ],
#        [123.8616  ],
#        [124.62831 ],
#        [125.05824 ],
#        [126.048195],
#        [126.89415 ],
#        [127.32523 ],
#        [127.72972 ],
#        [128.61815 ],
#        [128.21173 ],
#        [127.62914 ],
#        [127.45733 ],
#        [127.57572 ],
#        [128.05415 ],
#        [128.95206 ],
#        [129.24922 ],
#        [129.45766 ],
#        [132.03464 ],
#        [136.51842 ],
#        [140.59447 ],
#        [142.33887 ],
#        [143.74344 ],
#        [143.84068 ],
#        [143.24641 ],
#        [141.9476  ],
#        [140.64392 ],
#        [139.1182  ],
#        [138.6391  ],
#        [139.01965 ],
#        [140.2009  ],
#        [141.31552 ],
#        [141.3106  ],
#        [140.40881 ],
#        [139.3015  ],
#        [138.23546 ],
#        [139.54529 ],
#        [140.72035 ],
#        [141.95128 ],
#        [142.70427 ],
#        [142.70975 ],
#        [141.85551 ],
#        [140.72876 ],
#        [138.65771 ],
#        [137.79678 ],
#        [138.51862 ],
#        [141.11009 ],
#        [143.65527 ],
#        [145.62952 ],
#        [146.29846 ],
#        [144.9738  ],
#        [146.38217 ],
#        [148.67761 ],
#        [149.29285 ],
#        [149.4637  ],
#        [149.52872 ],
#        [149.40526 ],
#        [149.43475 ],
#        [150.11496 ],
#        [151.1706  ],
#        [152.11331 ],
#        [151.6116  ],
#        [150.73557 ],
#        [151.12311 ],
#        [151.35995 ],
#        [150.81578 ],
#        [149.70433 ],
#        [148.32945 ],
#        [148.24614 ],
#        [149.64577 ],
#        [150.78847 ],
#        [151.449   ],
#        [151.48862 ],
#        [152.02205 ],
#        [151.94496 ],
#        [151.93011 ],
#        [153.8518  ],
#        [155.3429  ],
#        [155.47395 ],
#        [153.66455 ],
#        [151.92004 ],
#        [151.71681 ],
#        [152.72485 ],
#        [153.48773 ],
#        [153.1875  ],
#        [153.30455 ],
#        [153.59622 ],
#        [153.14493 ],
#        [150.32867 ],
#        [148.39314 ],
#        [147.22511 ],
#        [145.68588 ],
#        [143.39531 ],
#        [142.22284 ],
#        [143.59903 ],
#        [145.08571 ],
#        [145.84558 ],
#        [147.32521 ],
#        [149.745   ],
#        [152.50597 ],
#        [154.19852 ],
#        [153.7611  ],
#        [153.509   ],
#        [153.2638  ],
#        [153.0756  ],
#        [152.1449  ],
#        [153.07745 ],
#        [155.51917 ],
#        [157.86308 ],
#        [158.66486 ],
#        [157.58266 ],
#        [156.3173  ],
#        [155.60855 ],
#        [154.63261 ],
#        [152.43938 ],
#        [149.12233 ],
#        [147.52417 ],
#        [147.30418 ],
#        [148.5984  ],
#        [150.3946  ],
#        [150.93321 ],
#        [152.93134 ],
#        [153.74014 ],
#        [155.17142 ],
#        [159.98091 ],
#        [165.62979 ],
#        [170.72968 ],
#        [173.83867 ],
#        [173.93584 ],
#        [173.94458 ],
#        [172.64099 ],
#        [172.10158 ],
#        [170.61743 ],
#        [169.9501  ],
#        [169.17613 ],
#        [169.31079 ],
#        [170.34784 ],
#        [169.45755 ],
#        [168.32886 ],
#        [167.86685 ],
#        [166.91408 ],
#        [164.97383 ],
#        [164.19893 ],
#        [164.29138 ],
#        [166.47385 ],
#        [166.53015 ],
#        [163.64398 ],
#        [158.22221 ],
#        [157.97089 ],
#        [166.94952 ],
#        [183.1141  ],
#        [192.8773  ],
#        [195.62689 ],
#        [194.67369 ],
#        [189.43483 ],
#        [188.67947 ],
#        [189.44571 ],
#        [189.91417 ],
#        [188.65218 ],
#        [191.1297  ],
#        [194.6012  ],
#        [196.11539 ],
#        [193.43448 ],
#        [192.2305  ],
#        [197.37856 ],
#        [201.97939 ],
#        [203.7982  ],
#        [204.55418 ],
#        [205.96724 ],
#        [204.02632 ],
#        [204.45886 ],
#        [204.95827 ],
#        [206.6955  ],
#        [209.64432 ],
#        [209.81583 ],
#        [207.79872 ],
#        [199.84447 ],
#        [191.97069 ],
#        [193.78333 ],
#        [195.19714 ],
#        [197.83702 ],
#        [201.03261 ],
#        [202.78465 ],
#        [201.82758 ],
#        [202.72612 ],
#        [203.91852 ],
#        [203.5968  ],
#        [202.93547 ],
#        [203.23192 ],
#        [205.35045 ],
#        [205.99568 ],
#        [205.26825 ],
#        [204.95738 ],
#        [203.07857 ],
#        [200.43971 ],
#        [198.35567 ],
#        [201.54813 ],
#        [202.53218 ],
#        [204.29826 ],
#        [211.50244 ],
#        [220.04205 ],
#        [223.43552 ],
#        [222.72878 ],
#        [219.91234 ],
#        [217.42749 ],
#        [222.44585 ],
#        [221.36362 ],
#        [218.10466 ],
#        [226.29341 ],
#        [231.00906 ],
#        [229.50844 ],
#        [234.233   ],
#        [240.71872 ],
#        [243.4918  ],
#        [247.6147  ],
#        [258.70987 ],
#        [263.00897 ],
#        [261.71814 ],
#        [259.8111  ],
#        [261.5682  ],
#        [262.31473 ],
#        [268.7858  ],
#        [267.287   ],
#        [268.44476 ],
#        [267.26575 ],
#        [262.784   ],
#        [261.1653  ],
#        [258.36288 ],
#        [263.29965 ],
#        [270.00266 ],
#        [278.34946 ],
#        [273.57343 ],
#        [265.54456 ],
#        [262.87793 ],
#        [265.88388 ],
#        [271.16547 ],
#        [279.71967 ],
#        [282.83093 ],
#        [281.05576 ],
#        [280.81512 ],
#        [283.36496 ],
#        [284.38782 ],
#        [284.7776  ],
#        [291.3404  ],
#        [292.20456 ],
#        [289.14236 ],
#        [287.4406  ],
#        [288.2447  ],
#        [289.5492  ],
#        [293.02234 ],
#        [292.72116 ],
#        [290.52072 ],
#        [288.9851  ],
#        [297.30664 ],
#        [299.8919  ],
#        [293.834   ],
#        [288.2775  ],
#        [282.03772 ],
#        [282.84018 ],
#        [285.71225 ],
#        [285.708   ],
#        [282.8118  ],
#        [281.41638 ],
#        [279.93945 ],
#        [281.09207 ],
#        [272.99335 ],
#        [266.97104 ],
#        [257.54877 ],
#        [253.59084 ],
#        [250.62639 ],
#        [259.65637 ],
#        [266.04376 ],
#        [264.77448 ],
#        [266.48856 ],
#        [265.76904 ],
#        [262.60464 ],
#        [258.91553 ],
#        [253.01299 ],
#        [247.8258  ],
#        [249.89589 ],
#        [250.19872 ],
#        [255.37866 ],
#        [260.29926 ],
#        [262.0718  ],
#        [261.48654 ],
#        [259.8962  ],
#        [259.56635 ],
#        [258.88712 ],
#        [255.10356 ],
#        [256.33383 ],
#        [255.18185 ],
#        [259.16806 ],
#        [263.42374 ],
#        [264.4588  ],
#        [264.15738 ],
#        [258.65955 ],
#        [247.45688 ],
#        [244.07756 ],
#        [247.06403 ],
#        [247.08913 ],
#        [245.48082 ],
#        [247.53593 ],
#        [250.34743 ],
#        [247.7337  ],
#        [257.01047 ],
#        [262.22394 ],
#        [258.59546 ],
#        [256.53802 ],
#        [256.61115 ],
#        [260.7424  ],
#        [261.7086  ],
#        [259.75104 ],
#        [258.43665 ],
#        [259.49454 ],
#        [263.23752 ],
#        [265.75284 ],
#        [267.8139  ],
#        [269.38376 ],
#        [269.4169  ],
#        [266.89886 ],
#        [265.09497 ],
#        [268.98166 ],
#        [273.11826 ],
#        [274.55197 ],
#        [277.57086 ],
#        [275.43677 ],
#        [268.90414 ],
#        [266.96487 ],
#        [272.53714 ],
#        [273.05255 ],
#        [272.92596 ],
#        [268.23938 ],
#        [267.2039  ],
#        [246.48628 ],
#        [226.4135  ],
#        [222.11218 ],
#        [231.05533 ],
#        [236.28438 ],
#        [235.53308 ],
#        [235.57553 ],
#        [237.69185 ],
#        [241.46758 ],
#        [245.12086 ],
#        [247.91129 ],
#        [246.4732  ],
#        [249.36002 ],
#        [255.15237 ],
#        [253.91037 ],
#        [245.85562 ],
#        [247.36864 ],
#        [252.7185  ],
#        [256.04608 ],
#        [255.94044 ],
#        [252.39479 ],
#        [252.65375 ],
#        [255.18304 ],
#        [261.6714  ],
#        [260.71747 ],
#        [259.68857 ],
#        [253.90857 ],
#        [246.5301  ],
#        [242.6135  ],
#        [245.6671  ],
#        [250.55302 ],
#        [254.23608 ],
#        [253.51067 ],
#        [250.52252 ],
#        [252.4781  ],
#        [251.3788  ],
#        [260.80658 ],
#        [264.56802 ],
#        [259.14514 ],
#        [251.50612 ],
#        [255.19554 ],
#        [259.75266 ],
#        [257.6431  ],
#        [251.86922 ],
#        [245.19743 ],
#        [232.82881 ],
#        [231.05449 ],
#        [228.6299  ],
#        [224.03033 ],
#        [225.79865 ],
#        [231.7797  ],
#        [236.72972 ],
#        [231.54211 ],
#        [227.52924 ],
#        [229.04698 ],
#        [231.51326 ],
#        [235.6361  ],
#        [230.58206 ],
#        [225.66508 ],
#        [224.26001 ],
#        [228.35136 ],
#        [230.56653 ],
#        [229.68532 ],
#        [228.92975 ],
#        [226.37831 ],
#        [225.39923 ],
#        [227.5752  ],
#        [230.4926  ],
#        [233.83704 ],
#        [236.30063 ],
#        [233.65747 ],
#        [227.5678  ],
#        [221.72604 ],
#        [224.00824 ],
#        [225.60109 ],
#        [226.46986 ],
#        [227.5354  ],
#        [226.85999 ],
#        [227.34901 ],
#        [219.74281 ],
#        [213.35042 ],
#        [211.28577 ],
#        [213.48984 ],
#        [215.36276 ],
#        [212.24812 ],
#        [213.33527 ],
#        [222.3408  ],
#        [229.93237 ],
#        [230.53105 ],
#        [227.76465 ],
#        [225.4477  ],
#        [224.07957 ],
#        [225.80292 ],
#        [226.5659  ]], dtype=float32)

# %% [markdown]
# ## Calculating the Performance

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
performance = math.sqrt(mean_squared_error(ytest,test_predict))
performance
# Out:
# 0.04637479618354425

# %% [markdown]
# ### Thank You
